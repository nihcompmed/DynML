# %%
# ============================================================
# DOUBLE-PENDULUM FULL MATCHED-ABLATION COMPARISON
# USING BD-CODE DATA CONVENTION
#
# Full matched-ablation model list:
#   1. Persistence
#   2. Direct ridge
#   3. Matched ESN
#   4. Random linear features
#   5. Random nonlinear features
#   6. Single Lorenz
#   7. Low-rho non-chaotic Lorenz
#   8. Homogeneous chaotic Lorenz
#   9. DynML heterogeneous Lorenz
#
# BD-style data/metric convention:
#   - first 8000 samples
#   - global input/output standardization before split
#   - random shuffled seeds
#   - metrics computed directly in standardized output space
#   - no inverse-transform before computing metrics
#
# Additional output:
#   - variable-wise metrics for theta_1, theta_2, omega_1, omega_2
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from pathlib import Path
from scipy.integrate import solve_ivp
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# ============================================================
# CONFIGURATION
# ============================================================

INPUT_CSV = Path("input_data_double_pendulum.csv")
OUTPUT_CSV = Path("output_data_double_pendulum.csv")
DATASET_NAME = "Double pendulum"

NUM_SAMPLES_TO_USE = 8000

N_FIXED = 150
FEATURE_DIM = 3 * N_FIXED

# Use 10 for practical runtime, or 30 for full consistency with BD analysis
PREDICTION_NUM_RANDOM_SEEDS = 10
TEST_FRACTION = 0.20

RIDGE_ALPHA_READOUT = 1e-6
RIDGE_ALPHA_BASELINE = 1.0

R_LOW, R_HIGH = 1.0, 30.0

T_INITIAL = 0.0
T_FINAL = 1.0
NUM_EVAL_POINTS = 500

RANDOM_FEATURE_SCALE = 1.0

ESN_SPECTRAL_RADIUS = 0.90
ESN_INPUT_SCALE = 0.50
ESN_LEAK_RATE = 1.00
ESN_SPARSITY = 0.10

OUTPUT_BY_SEED = "double_pendulum_matched_ablation_BD_style_by_seed.csv"
OUTPUT_SUMMARY = "double_pendulum_matched_ablation_BD_style_summary.csv"
OUTPUT_TABLE = "double_pendulum_matched_ablation_BD_style_table.csv"

OUTPUT_VARIABLE_BY_SEED = (
    "double_pendulum_matched_ablation_BD_style_variablewise_by_seed.csv"
)
OUTPUT_VARIABLE_SUMMARY = (
    "double_pendulum_matched_ablation_BD_style_variablewise_summary.csv"
)
OUTPUT_VARIABLE_TABLE = (
    "double_pendulum_matched_ablation_BD_style_variablewise_table.csv"
)

OUTPUT_NAMES = [
    "theta_1",
    "theta_2",
    "omega_1",
    "omega_2"
]


# ============================================================
# LOAD DATA USING BD-CODE STYLE
# ============================================================

if not INPUT_CSV.exists():
    raise FileNotFoundError(f"Could not find {INPUT_CSV}")

if not OUTPUT_CSV.exists():
    raise FileNotFoundError(f"Could not find {OUTPUT_CSV}")

input_data = pd.read_csv(INPUT_CSV).iloc[:, 1:NUM_SAMPLES_TO_USE + 1].values
output_data = pd.read_csv(OUTPUT_CSV).iloc[:, 1:NUM_SAMPLES_TO_USE + 1].values

D = input_data.shape[1]
M = input_data.shape[0]
P = output_data.shape[0]

print("Loaded data")
print("-----------")
print("Dataset:", DATASET_NAME)
print("Input shape:", input_data.shape)
print("Output shape:", output_data.shape)
print("Samples D:", D)
print("Input features M:", M)
print("Output features P:", P)
print("N fixed:", N_FIXED)
print("Matched feature dimension:", FEATURE_DIM)

if input_data.shape[1] != output_data.shape[1]:
    raise ValueError("Input and output have different numbers of samples.")

if not np.all(np.isfinite(input_data)):
    raise ValueError("Input data contain NaN or infinite values.")

if not np.all(np.isfinite(output_data)):
    raise ValueError("Output data contain NaN or infinite values.")

if M != 4 or P != 4:
    print()
    print("WARNING:")
    print("Expected double-pendulum direct-transition files to have M=4 and P=4.")
    print("Your files have M =", M, "and P =", P)
    print("Check that these are the corrected direct-transition files.")


# ============================================================
# GLOBAL STANDARDIZATION BEFORE SPLIT, SAME AS BD CODE
# ============================================================

scaler_input = StandardScaler()
input_data_norm = scaler_input.fit_transform(input_data.T).T

scaler_output = StandardScaler()
output_data_norm = scaler_output.fit_transform(output_data.T).T

print()
print("Standardized data")
print("-----------------")
print("input_data_norm shape:", input_data_norm.shape)
print("output_data_norm shape:", output_data_norm.shape)


# ============================================================
# METRICS IN STANDARDIZED OUTPUT SPACE
# ============================================================

def compute_regression_metrics(y_true, y_pred):
    """
    Compute pooled metrics in the same standardized space.

    y_true, y_pred shape:
        num_outputs x num_samples
    """

    yt = np.asarray(y_true).reshape(-1)
    yp = np.asarray(y_pred).reshape(-1)

    rmse = np.sqrt(mean_squared_error(yt, yp))
    mae = mean_absolute_error(yt, yp)
    r2 = r2_score(yt, yp)

    if np.std(yt) > 0 and np.std(yp) > 0:
        pearson_r, pearson_p = pearsonr(yt, yp)
    else:
        pearson_r, pearson_p = np.nan, np.nan

    if np.std(yt) > 0:
        calibration_slope, calibration_intercept = np.polyfit(yt, yp, 1)
    else:
        calibration_slope, calibration_intercept = np.nan, np.nan

    return {
        "pearson_r": pearson_r,
        "pearson_p": pearson_p,
        "rmse": rmse,
        "mae": mae,
        "r2": r2,
        "calibration_slope": calibration_slope,
        "calibration_intercept": calibration_intercept
    }


def compute_metrics_per_output(y_true, y_pred, output_names):
    """
    Compute variable-wise metrics in standardized output space.

    y_true, y_pred shape:
        num_outputs x num_samples
    """

    rows = []

    for i, name in enumerate(output_names):
        yt = y_true[i, :]
        yp = y_pred[i, :]

        rmse = np.sqrt(mean_squared_error(yt, yp))
        mae = mean_absolute_error(yt, yp)
        r2 = r2_score(yt, yp)

        if np.std(yt) > 0 and np.std(yp) > 0:
            pearson_r, pearson_p = pearsonr(yt, yp)
        else:
            pearson_r, pearson_p = np.nan, np.nan

        if np.std(yt) > 0:
            calibration_slope, calibration_intercept = np.polyfit(yt, yp, 1)
        else:
            calibration_slope, calibration_intercept = np.nan, np.nan

        rows.append({
            "output": name,
            "pearson_r": pearson_r,
            "pearson_p": pearson_p,
            "rmse": rmse,
            "mae": mae,
            "r2": r2,
            "calibration_slope": calibration_slope,
            "calibration_intercept": calibration_intercept
        })

    return pd.DataFrame(rows)


def summarize_metrics(metrics_df):
    metric_cols = [
        "pearson_r",
        "rmse",
        "mae",
        "r2",
        "calibration_slope",
        "calibration_intercept"
    ]

    rows = []

    grouped = metrics_df.groupby(
        ["dataset", "model", "split", "feature_dim"],
        dropna=False
    )

    for keys, group in grouped:
        dataset, model, split, feature_dim = keys

        row = {
            "dataset": dataset,
            "model": model,
            "split": split,
            "feature_dim": feature_dim,
            "n_seeds": group["seed_id"].nunique()
        }

        for metric in metric_cols:
            values = group[metric].dropna().values
            n = len(values)

            mean = np.mean(values) if n > 0 else np.nan
            sd = np.std(values, ddof=1) if n > 1 else np.nan
            sem = sd / np.sqrt(n) if n > 1 else np.nan
            ci95 = 1.96 * sem if n > 1 else np.nan

            row[f"{metric}_mean"] = mean
            row[f"{metric}_sd"] = sd
            row[f"{metric}_ci95"] = ci95

        rows.append(row)

    return pd.DataFrame(rows)


def summarize_variable_metrics(variable_df):
    metric_cols = [
        "pearson_r",
        "rmse",
        "mae",
        "r2",
        "calibration_slope",
        "calibration_intercept"
    ]

    rows = []

    grouped = variable_df.groupby(
        ["dataset", "model", "split", "output"],
        dropna=False
    )

    for keys, group in grouped:
        dataset, model, split, output = keys

        row = {
            "dataset": dataset,
            "model": model,
            "split": split,
            "output": output,
            "n_seeds": group["seed_id"].nunique()
        }

        for metric in metric_cols:
            values = group[metric].dropna().values
            n = len(values)

            mean = np.mean(values) if n > 0 else np.nan
            sd = np.std(values, ddof=1) if n > 1 else np.nan
            sem = sd / np.sqrt(n) if n > 1 else np.nan
            ci95 = 1.96 * sem if n > 1 else np.nan

            row[f"{metric}_mean"] = mean
            row[f"{metric}_sd"] = sd
            row[f"{metric}_ci95"] = ci95

        rows.append(row)

    return pd.DataFrame(rows)


def format_mean_ci(mean, ci):
    if pd.isna(mean):
        return "NA"
    if pd.isna(ci):
        return f"{mean:.4f}"
    return f"{mean:.4f} ± {ci:.4f}"


# ============================================================
# LORENZ SYSTEM
# Parameter order:
#   sigma, beta, rho, tau
# ============================================================

def lorenz_system(t, X, params):
    X = X.reshape(len(params), 3)

    sigma = params[:, 0]
    beta = params[:, 1]
    rho = params[:, 2]
    tau = params[:, 3]

    dxdt = (1.0 / tau) * sigma * (X[:, 1] - X[:, 0])
    dydt = (1.0 / tau) * (X[:, 0] * (rho - X[:, 2]) - X[:, 1])
    dzdt = (1.0 / tau) * (X[:, 0] * X[:, 1] - beta * X[:, 2])

    return np.stack([dxdt, dydt, dzdt], axis=1).flatten()


# ============================================================
# LORENZ PARAMETER MODES FOR MATCHED ABLATION
# ============================================================

def build_lorenz_params(mode, n_reservoirs, seed):
    rng = np.random.default_rng(seed)

    if mode == "single_lorenz":
        params = np.array([
            [
                10.0,        # sigma
                8.0 / 3.0,   # beta
                28.0,        # rho
                1.0          # tau
            ]
        ])

    elif mode == "low_rho_nonchaotic":
        params = np.tile(
            [
                10.0,        # sigma
                8.0 / 3.0,   # beta
                10.0,        # rho
                1.0          # tau
            ],
            (n_reservoirs, 1)
        )

    elif mode == "homogeneous_chaotic":
        params = np.tile(
            [
                10.0,        # sigma
                8.0 / 3.0,   # beta
                28.0,        # rho
                1.0          # tau
            ],
            (n_reservoirs, 1)
        )

    elif mode == "heterogeneous_chaotic":
        params = np.array([
            [
                rng.uniform(9.9, 10.1),     # sigma
                rng.uniform(2.65, 2.70),    # beta
                rng.uniform(27.9, 28.1),    # rho
                rng.uniform(1.0, 10.0)      # tau
            ]
            for _ in range(n_reservoirs)
        ])

    else:
        raise ValueError(f"Unknown Lorenz mode: {mode}")

    return params


# ============================================================
# LORENZ FEATURE GENERATION
# ============================================================

def compute_lorenz_features(X_norm, seed, mode, n_reservoirs):
    """
    Generate final Lorenz reservoir states.

    X_norm shape:
        input_dim x num_samples

    returns:
        feature_dim x num_samples
    """

    rng = np.random.default_rng(seed)

    M_local = X_norm.shape[0]
    D_local = X_norm.shape[1]

    reservoir_params = build_lorenz_params(
        mode=mode,
        n_reservoirs=n_reservoirs,
        seed=seed
    )

    R = rng.uniform(R_LOW, R_HIGH, size=(3 * n_reservoirs, M_local))

    t_eval = np.linspace(T_INITIAL, T_FINAL, NUM_EVAL_POINTS)
    features = np.zeros((3 * n_reservoirs, D_local))

    for j in range(D_local):
        if j % 1000 == 0:
            print(f"    Lorenz feature sample {j + 1}/{D_local}")

        x0 = R @ X_norm[:, j]

        sol = solve_ivp(
            lorenz_system,
            (T_INITIAL, T_FINAL),
            x0,
            t_eval=t_eval,
            args=(reservoir_params,),
            method="RK45",
            rtol=1e-6,
            atol=1e-9
        )

        if not sol.success:
            raise RuntimeError(
                f"ODE integration failed for sample {j}, mode={mode}: {sol.message}"
            )

        features[:, j] = sol.y[:, -1]

    return features


# ============================================================
# RANDOM FEATURE BASELINES
# ============================================================

def compute_random_linear_features(X_norm, seed, feature_dim):
    rng = np.random.default_rng(seed)
    M_local = X_norm.shape[0]

    R = rng.normal(
        loc=0.0,
        scale=RANDOM_FEATURE_SCALE / np.sqrt(M_local),
        size=(feature_dim, M_local)
    )

    return R @ X_norm


def compute_random_nonlinear_features(X_norm, seed, feature_dim):
    rng = np.random.default_rng(seed)
    M_local = X_norm.shape[0]

    R = rng.normal(
        loc=0.0,
        scale=RANDOM_FEATURE_SCALE / np.sqrt(M_local),
        size=(feature_dim, M_local)
    )

    b = rng.uniform(-1.0, 1.0, size=(feature_dim, 1))

    return np.tanh(R @ X_norm + b)


# ============================================================
# MATCHED ESN BASELINE
# ============================================================

def rescale_spectral_radius(W, target_radius):
    eigvals = np.linalg.eigvals(W)
    radius = np.max(np.abs(eigvals))

    if radius == 0 or not np.isfinite(radius):
        return W

    return W * (target_radius / radius)


def compute_esn_features(X_norm, seed, n_units):
    """
    Matched ESN baseline for direct-transition targets.

    Each input vector is treated as a one-step driven input.
    The final ESN state is used as the feature representation.
    """

    rng = np.random.default_rng(seed)

    M_local = X_norm.shape[0]
    D_local = X_norm.shape[1]

    W = rng.uniform(-1.0, 1.0, size=(n_units, n_units))
    mask = rng.uniform(0.0, 1.0, size=(n_units, n_units)) < ESN_SPARSITY
    W = W * mask
    W = rescale_spectral_radius(W, ESN_SPECTRAL_RADIUS)

    Win = rng.uniform(
        -ESN_INPUT_SCALE,
        ESN_INPUT_SCALE,
        size=(n_units, M_local)
    )

    features = np.zeros((n_units, D_local))

    for j in range(D_local):
        u = X_norm[:, j]
        x_state = np.zeros(n_units)

        pre_activation = W @ x_state + Win @ u
        x_new = np.tanh(pre_activation)
        x_state = (1.0 - ESN_LEAK_RATE) * x_state + ESN_LEAK_RATE * x_new

        features[:, j] = x_state

    return features


# ============================================================
# READOUT EVALUATION IN BD STANDARDIZED SPACE
# ============================================================

def fit_ridge_readout(X_train_features, Y_train, alpha):
    model = Ridge(alpha=alpha, fit_intercept=True)
    model.fit(X_train_features.T, Y_train.T)
    return model


def evaluate_feature_model(
    model_name,
    feature_dim,
    features,
    train_indices,
    test_indices,
    Y_train,
    Y_test,
    alpha
):
    X_train_features = features[:, train_indices]
    X_test_features = features[:, test_indices]

    model = fit_ridge_readout(
        X_train_features=X_train_features,
        Y_train=Y_train,
        alpha=alpha
    )

    pred_train = model.predict(X_train_features.T).T
    pred_test = model.predict(X_test_features.T).T

    train_metrics = compute_regression_metrics(Y_train, pred_train)
    test_metrics = compute_regression_metrics(Y_test, pred_test)

    rows = [
        {
            "dataset": DATASET_NAME,
            "model": model_name,
            "feature_dim": feature_dim,
            "split": "train",
            **train_metrics
        },
        {
            "dataset": DATASET_NAME,
            "model": model_name,
            "feature_dim": feature_dim,
            "split": "test",
            **test_metrics
        }
    ]

    return rows, pred_train, pred_test


# ============================================================
# MAIN EVALUATION LOOP
# ============================================================

all_seed_metrics = []
all_variable_metrics = []

start_time = time.time()

for seed_id in range(PREDICTION_NUM_RANDOM_SEEDS):

    print("\n" + "=" * 90)
    print(f"Prediction seed {seed_id + 1}/{PREDICTION_NUM_RANDOM_SEEDS}")
    print("=" * 90)

    rng = np.random.default_rng(2000 + seed_id)

    all_indices = np.arange(D)
    rng.shuffle(all_indices)

    n_test = int(TEST_FRACTION * D)
    test_indices = all_indices[:n_test]
    train_indices = all_indices[n_test:]

    X_train_input = input_data_norm[:, train_indices]
    X_test_input = input_data_norm[:, test_indices]

    Y_train = output_data_norm[:, train_indices]
    Y_test = output_data_norm[:, test_indices]

    X_all_norm = input_data_norm

    seed_predictions = {}

    # ------------------------------------------------------------
    # 1. Persistence baseline
    # ------------------------------------------------------------

    if M == P:
        Y_pred_persistence_train = X_train_input.copy()
        Y_pred_persistence_test = X_test_input.copy()

        train_metrics = compute_regression_metrics(Y_train, Y_pred_persistence_train)
        test_metrics = compute_regression_metrics(Y_test, Y_pred_persistence_test)

        for split_name, metrics in [
            ("train", train_metrics),
            ("test", test_metrics)
        ]:
            all_seed_metrics.append({
                "dataset": DATASET_NAME,
                "seed_id": seed_id,
                "model": "Persistence",
                "feature_dim": M,
                "split": split_name,
                **metrics
            })

        seed_predictions["Persistence"] = (
            Y_pred_persistence_train,
            Y_pred_persistence_test
        )

    # ------------------------------------------------------------
    # 2. Direct ridge baseline
    # ------------------------------------------------------------

    ridge_baseline = Ridge(alpha=RIDGE_ALPHA_BASELINE, fit_intercept=True)
    ridge_baseline.fit(X_train_input.T, Y_train.T)

    Y_pred_ridge_train = ridge_baseline.predict(X_train_input.T).T
    Y_pred_ridge_test = ridge_baseline.predict(X_test_input.T).T

    train_metrics = compute_regression_metrics(Y_train, Y_pred_ridge_train)
    test_metrics = compute_regression_metrics(Y_test, Y_pred_ridge_test)

    for split_name, metrics in [
        ("train", train_metrics),
        ("test", test_metrics)
    ]:
        all_seed_metrics.append({
            "dataset": DATASET_NAME,
            "seed_id": seed_id,
            "model": "Direct ridge",
            "feature_dim": M,
            "split": split_name,
            **metrics
        })

    seed_predictions["Direct ridge"] = (
        Y_pred_ridge_train,
        Y_pred_ridge_test
    )

    # ------------------------------------------------------------
    # 3. Matched ESN
    # ------------------------------------------------------------

    print("Generating matched ESN features")

    phi_esn = compute_esn_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        n_units=FEATURE_DIM
    )

    rows, esn_train, esn_test = evaluate_feature_model(
        model_name="Matched ESN",
        feature_dim=FEATURE_DIM,
        features=phi_esn,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Matched ESN"] = (esn_train, esn_test)

    # ------------------------------------------------------------
    # 4. Random linear features
    # ------------------------------------------------------------

    print("Generating random linear features")

    phi_random_linear = compute_random_linear_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        feature_dim=FEATURE_DIM
    )

    rows, random_linear_train, random_linear_test = evaluate_feature_model(
        model_name="Random linear features",
        feature_dim=FEATURE_DIM,
        features=phi_random_linear,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Random linear features"] = (
        random_linear_train,
        random_linear_test
    )

    # ------------------------------------------------------------
    # 5. Random nonlinear features
    # ------------------------------------------------------------

    print("Generating random nonlinear features")

    phi_random_nonlinear = compute_random_nonlinear_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        feature_dim=FEATURE_DIM
    )

    rows, random_nonlinear_train, random_nonlinear_test = evaluate_feature_model(
        model_name="Random nonlinear features",
        feature_dim=FEATURE_DIM,
        features=phi_random_nonlinear,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Random nonlinear features"] = (
        random_nonlinear_train,
        random_nonlinear_test
    )

    # ------------------------------------------------------------
    # 6. Single Lorenz reservoir
    # ------------------------------------------------------------

    print("Generating single Lorenz features")

    phi_single = compute_lorenz_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        mode="single_lorenz",
        n_reservoirs=1
    )

    rows, single_train, single_test = evaluate_feature_model(
        model_name="Single Lorenz",
        feature_dim=3,
        features=phi_single,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Single Lorenz"] = (single_train, single_test)

    # ------------------------------------------------------------
    # 7. Low-rho non-chaotic Lorenz
    # ------------------------------------------------------------

    print("Generating low-rho non-chaotic Lorenz features")

    phi_lowrho = compute_lorenz_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        mode="low_rho_nonchaotic",
        n_reservoirs=N_FIXED
    )

    rows, lowrho_train, lowrho_test = evaluate_feature_model(
        model_name="Low-rho non-chaotic Lorenz",
        feature_dim=FEATURE_DIM,
        features=phi_lowrho,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Low-rho non-chaotic Lorenz"] = (
        lowrho_train,
        lowrho_test
    )

    # ------------------------------------------------------------
    # 8. Homogeneous chaotic Lorenz
    # ------------------------------------------------------------

    print("Generating homogeneous chaotic Lorenz features")

    phi_homogeneous = compute_lorenz_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        mode="homogeneous_chaotic",
        n_reservoirs=N_FIXED
    )

    rows, homogeneous_train, homogeneous_test = evaluate_feature_model(
        model_name="Homogeneous chaotic Lorenz",
        feature_dim=FEATURE_DIM,
        features=phi_homogeneous,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["Homogeneous chaotic Lorenz"] = (
        homogeneous_train,
        homogeneous_test
    )

    # ------------------------------------------------------------
    # 9. DynML heterogeneous Lorenz
    # ------------------------------------------------------------

    print("Generating DynML heterogeneous Lorenz features")

    phi_dynml = compute_lorenz_features(
        X_norm=X_all_norm,
        seed=2000 + seed_id,
        mode="heterogeneous_chaotic",
        n_reservoirs=N_FIXED
    )

    rows, dynml_train, dynml_test = evaluate_feature_model(
        model_name="DynML heterogeneous Lorenz",
        feature_dim=FEATURE_DIM,
        features=phi_dynml,
        train_indices=train_indices,
        test_indices=test_indices,
        Y_train=Y_train,
        Y_test=Y_test,
        alpha=RIDGE_ALPHA_READOUT
    )

    for row in rows:
        row["seed_id"] = seed_id
        all_seed_metrics.append(row)

    seed_predictions["DynML heterogeneous Lorenz"] = (
        dynml_train,
        dynml_test
    )

    # ------------------------------------------------------------
    # Variable-wise test metrics for this seed
    # ------------------------------------------------------------

    for model_name, (_, pred_test) in seed_predictions.items():
        variable_df = compute_metrics_per_output(
            y_true=Y_test,
            y_pred=pred_test,
            output_names=OUTPUT_NAMES
        )

        variable_df["dataset"] = DATASET_NAME
        variable_df["seed_id"] = seed_id
        variable_df["model"] = model_name
        variable_df["split"] = "test"

        all_variable_metrics.append(variable_df)

    # ------------------------------------------------------------
    # Print seed-level pooled test metrics
    # ------------------------------------------------------------

    print()
    print("Pooled test metrics, standardized output space")
    print("----------------------------------------------")

    feature_dim_lookup = {
        "Persistence": M,
        "Direct ridge": M,
        "Matched ESN": FEATURE_DIM,
        "Random linear features": FEATURE_DIM,
        "Random nonlinear features": FEATURE_DIM,
        "Single Lorenz": 3,
        "Low-rho non-chaotic Lorenz": FEATURE_DIM,
        "Homogeneous chaotic Lorenz": FEATURE_DIM,
        "DynML heterogeneous Lorenz": FEATURE_DIM
    }

    for model_name, (_, pred_test) in seed_predictions.items():
        metrics = compute_regression_metrics(Y_test, pred_test)

        print(
            f"{model_name:32s} "
            f"features={feature_dim_lookup[model_name]:3d} "
            f"r={metrics['pearson_r']:.4f}, "
            f"RMSE={metrics['rmse']:.4f}, "
            f"MAE={metrics['mae']:.4f}, "
            f"R2={metrics['r2']:.4f}, "
            f"slope={metrics['calibration_slope']:.4f}, "
            f"intercept={metrics['calibration_intercept']:.4f}"
        )


# ============================================================
# SAVE POOLED METRICS
# ============================================================

metrics_df = pd.DataFrame(all_seed_metrics)

preferred_cols = [
    "dataset",
    "seed_id",
    "model",
    "feature_dim",
    "split",
    "pearson_r",
    "pearson_p",
    "rmse",
    "mae",
    "r2",
    "calibration_slope",
    "calibration_intercept"
]

metrics_df = metrics_df[preferred_cols]
metrics_df.to_csv(OUTPUT_BY_SEED, index=False)

summary_df = summarize_metrics(metrics_df)
summary_df.to_csv(OUTPUT_SUMMARY, index=False)

test_summary = summary_df[summary_df["split"] == "test"].copy()

model_order = [
    "Persistence",
    "Direct ridge",
    "Matched ESN",
    "Random linear features",
    "Random nonlinear features",
    "Single Lorenz",
    "Low-rho non-chaotic Lorenz",
    "Homogeneous chaotic Lorenz",
    "DynML heterogeneous Lorenz"
]

table_rows = []

for _, row in test_summary.iterrows():
    table_rows.append({
        "Dataset": row["dataset"],
        "Model": row["model"],
        "Feature dimension": int(row["feature_dim"]),
        "Pearson r": format_mean_ci(
            row["pearson_r_mean"],
            row["pearson_r_ci95"]
        ),
        "RMSE": format_mean_ci(
            row["rmse_mean"],
            row["rmse_ci95"]
        ),
        "MAE": format_mean_ci(
            row["mae_mean"],
            row["mae_ci95"]
        ),
        "R2": format_mean_ci(
            row["r2_mean"],
            row["r2_ci95"]
        ),
        "Calibration slope": format_mean_ci(
            row["calibration_slope_mean"],
            row["calibration_slope_ci95"]
        ),
        "Calibration intercept": format_mean_ci(
            row["calibration_intercept_mean"],
            row["calibration_intercept_ci95"]
        )
    })

table_df = pd.DataFrame(table_rows)

table_df["model_order"] = table_df["Model"].map(
    {model: i for i, model in enumerate(model_order)}
)

table_df = table_df.sort_values("model_order").drop(columns=["model_order"])
table_df.to_csv(OUTPUT_TABLE, index=False)


# ============================================================
# SAVE VARIABLE-WISE METRICS
# ============================================================

variable_metrics_df = pd.concat(all_variable_metrics, ignore_index=True)

variable_cols = [
    "dataset",
    "seed_id",
    "model",
    "split",
    "output",
    "pearson_r",
    "pearson_p",
    "rmse",
    "mae",
    "r2",
    "calibration_slope",
    "calibration_intercept"
]

variable_metrics_df = variable_metrics_df[variable_cols]
variable_metrics_df.to_csv(OUTPUT_VARIABLE_BY_SEED, index=False)

variable_summary_df = summarize_variable_metrics(variable_metrics_df)
variable_summary_df.to_csv(OUTPUT_VARIABLE_SUMMARY, index=False)

variable_test_summary = variable_summary_df[
    variable_summary_df["split"] == "test"
].copy()

output_order = {
    "theta_1": 0,
    "theta_2": 1,
    "omega_1": 2,
    "omega_2": 3
}

variable_table_rows = []

for _, row in variable_test_summary.iterrows():
    variable_table_rows.append({
        "Dataset": row["dataset"],
        "Model": row["model"],
        "Output": row["output"],
        "Pearson r": format_mean_ci(
            row["pearson_r_mean"],
            row["pearson_r_ci95"]
        ),
        "RMSE": format_mean_ci(
            row["rmse_mean"],
            row["rmse_ci95"]
        ),
        "MAE": format_mean_ci(
            row["mae_mean"],
            row["mae_ci95"]
        ),
        "R2": format_mean_ci(
            row["r2_mean"],
            row["r2_ci95"]
        ),
        "Calibration slope": format_mean_ci(
            row["calibration_slope_mean"],
            row["calibration_slope_ci95"]
        ),
        "Calibration intercept": format_mean_ci(
            row["calibration_intercept_mean"],
            row["calibration_intercept_ci95"]
        )
    })

variable_table_df = pd.DataFrame(variable_table_rows)

variable_table_df["model_order"] = variable_table_df["Model"].map(
    {model: i for i, model in enumerate(model_order)}
)
variable_table_df["output_order"] = variable_table_df["Output"].map(output_order)

variable_table_df = (
    variable_table_df
    .sort_values(["model_order", "output_order"])
    .drop(columns=["model_order", "output_order"])
)

variable_table_df.to_csv(OUTPUT_VARIABLE_TABLE, index=False)


# ============================================================
# FINAL PRINT
# ============================================================

print()
print("Saved pooled metrics")
print("--------------------")
print(OUTPUT_BY_SEED)
print(OUTPUT_SUMMARY)
print(OUTPUT_TABLE)

print()
print("Table-ready pooled test metrics, standardized output space")
print("----------------------------------------------------------")
print(table_df.to_string(index=False))

print()
print("Saved variable-wise metrics")
print("---------------------------")
print(OUTPUT_VARIABLE_BY_SEED)
print(OUTPUT_VARIABLE_SUMMARY)
print(OUTPUT_VARIABLE_TABLE)

print()
print("Table-ready variable-wise test metrics, standardized output space")
print("-----------------------------------------------------------------")
print(variable_table_df.to_string(index=False))

print()
print(f"Total time: {time.time() - start_time:.2f} seconds")
# Out:
# /Users/halders2/.local/lib/python3.13/site-packages/pandas/core/computation/expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Loaded data
# -----------
# Dataset: Double pendulum
# Input shape: (4, 8000)
# Output shape: (4, 8000)
# Samples D: 8000
# Input features M: 4
# Output features P: 4
# N fixed: 150
# Matched feature dimension: 450
#
# Standardized data
# -----------------
# input_data_norm shape: (4, 8000)
# output_data_norm shape: (4, 8000)
#
# ==========================================================================================
# Prediction seed 1/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1781, RMSE=1.2772, MAE=0.9806, R2=-0.6370, slope=0.1773, intercept=-0.0093
# Direct ridge                     features=  4 r=0.4468, RMSE=0.8931, MAE=0.7246, R2=0.1995, slope=0.1963, intercept=-0.0077
# Matched ESN                      features=450 r=0.4055, RMSE=0.9244, MAE=0.7274, R2=0.1425, slope=0.2241, intercept=-0.0183
# Random linear features           features=450 r=0.4468, RMSE=0.8931, MAE=0.7246, R2=0.1995, slope=0.1963, intercept=-0.0077
# Random nonlinear features        features=450 r=0.3925, RMSE=0.9358, MAE=0.7276, R2=0.1212, slope=0.2252, intercept=-0.0114
# Single Lorenz                    features=  3 r=0.0641, RMSE=0.9962, MAE=0.8225, R2=0.0041, slope=0.0041, intercept=0.0015
# Low-rho non-chaotic Lorenz       features=450 r=0.3449, RMSE=0.9492, MAE=0.7663, R2=0.0958, slope=0.1715, intercept=-0.0080
# Homogeneous chaotic Lorenz       features=450 r=0.3172, RMSE=0.9580, MAE=0.7748, R2=0.0790, slope=0.1472, intercept=-0.0088
# DynML heterogeneous Lorenz       features=450 r=0.3809, RMSE=0.9365, MAE=0.7419, R2=0.1199, slope=0.2056, intercept=-0.0067
#
# ==========================================================================================
# Prediction seed 2/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1959, RMSE=1.2668, MAE=0.9722, R2=-0.6058, slope=0.1956, intercept=0.0118
# Direct ridge                     features=  4 r=0.4477, RMSE=0.8939, MAE=0.7255, R2=0.2004, slope=0.2016, intercept=-0.0003
# Matched ESN                      features=450 r=0.3980, RMSE=0.9332, MAE=0.7272, R2=0.1286, slope=0.2271, intercept=0.0052
# Random linear features           features=450 r=0.4477, RMSE=0.8939, MAE=0.7255, R2=0.2004, slope=0.2017, intercept=-0.0003
# Random nonlinear features        features=450 r=0.4283, RMSE=0.9128, MAE=0.7278, R2=0.1662, slope=0.2396, intercept=0.0006
# Single Lorenz                    features=  3 r=0.0607, RMSE=0.9980, MAE=0.8240, R2=0.0033, slope=0.0049, intercept=-0.0004
# Low-rho non-chaotic Lorenz       features=450 r=0.3623, RMSE=0.9410, MAE=0.7612, R2=0.1140, slope=0.1789, intercept=0.0013
# Homogeneous chaotic Lorenz       features=450 r=0.3167, RMSE=0.9603, MAE=0.7785, R2=0.0772, slope=0.1484, intercept=0.0075
# DynML heterogeneous Lorenz       features=450 r=0.4240, RMSE=0.9117, MAE=0.7286, R2=0.1682, slope=0.2253, intercept=0.0014
#
# ==========================================================================================
# Prediction seed 3/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1963, RMSE=1.2754, MAE=0.9777, R2=-0.6175, slope=0.1975, intercept=0.0035
# Direct ridge                     features=  4 r=0.4470, RMSE=0.8972, MAE=0.7257, R2=0.1996, slope=0.2045, intercept=-0.0046
# Matched ESN                      features=450 r=0.3822, RMSE=0.9555, MAE=0.7295, R2=0.0922, slope=0.2347, intercept=-0.0043
# Random linear features           features=450 r=0.4470, RMSE=0.8972, MAE=0.7257, R2=0.1996, slope=0.2045, intercept=-0.0046
# Random nonlinear features        features=450 r=0.4188, RMSE=0.9244, MAE=0.7244, R2=0.1504, slope=0.2416, intercept=0.0004
# Single Lorenz                    features=  3 r=0.0310, RMSE=1.0025, MAE=0.8241, R2=0.0007, slope=0.0013, intercept=-0.0019
# Low-rho non-chaotic Lorenz       features=450 r=0.3264, RMSE=0.9616, MAE=0.7802, R2=0.0805, slope=0.1591, intercept=-0.0017
# Homogeneous chaotic Lorenz       features=450 r=0.3198, RMSE=0.9606, MAE=0.7763, R2=0.0825, slope=0.1470, intercept=-0.0059
# DynML heterogeneous Lorenz       features=450 r=0.4050, RMSE=0.9292, MAE=0.7369, R2=0.1415, slope=0.2247, intercept=0.0013
#
# ==========================================================================================
# Prediction seed 4/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1916, RMSE=1.2718, MAE=0.9764, R2=-0.6289, slope=0.1929, intercept=-0.0060
# Direct ridge                     features=  4 r=0.4543, RMSE=0.8878, MAE=0.7191, R2=0.2062, slope=0.2058, intercept=0.0003
# Matched ESN                      features=450 r=0.3680, RMSE=0.9709, MAE=0.7251, R2=0.0506, slope=0.2425, intercept=0.0065
# Random linear features           features=450 r=0.4543, RMSE=0.8878, MAE=0.7191, R2=0.2062, slope=0.2058, intercept=0.0003
# Random nonlinear features        features=450 r=0.4214, RMSE=0.9185, MAE=0.7246, R2=0.1505, slope=0.2466, intercept=-0.0006
# Single Lorenz                    features=  3 r=0.0831, RMSE=0.9934, MAE=0.8187, R2=0.0062, slope=0.0067, intercept=-0.0062
# Low-rho non-chaotic Lorenz       features=450 r=0.3579, RMSE=0.9407, MAE=0.7593, R2=0.1088, slope=0.1767, intercept=-0.0115
# Homogeneous chaotic Lorenz       features=450 r=0.3039, RMSE=0.9619, MAE=0.7784, R2=0.0682, slope=0.1382, intercept=-0.0178
# DynML heterogeneous Lorenz       features=450 r=0.4158, RMSE=0.9163, MAE=0.7319, R2=0.1544, slope=0.2287, intercept=-0.0070
#
# ==========================================================================================
# Prediction seed 5/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.2114, RMSE=1.2548, MAE=0.9612, R2=-0.5566, slope=0.2086, intercept=0.0002
# Direct ridge                     features=  4 r=0.4494, RMSE=0.8985, MAE=0.7287, R2=0.2020, slope=0.1994, intercept=-0.0020
# Matched ESN                      features=450 r=0.4163, RMSE=0.9254, MAE=0.7277, R2=0.1534, slope=0.2321, intercept=-0.0048
# Random linear features           features=450 r=0.4494, RMSE=0.8984, MAE=0.7287, R2=0.2020, slope=0.1995, intercept=-0.0020
# Random nonlinear features        features=450 r=0.4302, RMSE=0.9163, MAE=0.7253, R2=0.1699, slope=0.2382, intercept=-0.0021
# Single Lorenz                    features=  3 r=0.0583, RMSE=1.0040, MAE=0.8283, R2=0.0034, slope=0.0034, intercept=0.0023
# Low-rho non-chaotic Lorenz       features=450 r=0.3371, RMSE=0.9585, MAE=0.7766, R2=0.0918, slope=0.1635, intercept=0.0065
# Homogeneous chaotic Lorenz       features=450 r=0.3366, RMSE=0.9558, MAE=0.7768, R2=0.0969, slope=0.1564, intercept=-0.0089
# DynML heterogeneous Lorenz       features=450 r=0.4203, RMSE=0.9195, MAE=0.7358, R2=0.1641, slope=0.2236, intercept=-0.0053
#
# ==========================================================================================
# Prediction seed 6/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1812, RMSE=1.2638, MAE=0.9731, R2=-0.6296, slope=0.1803, intercept=-0.0048
# Direct ridge                     features=  4 r=0.4307, RMSE=0.8934, MAE=0.7279, R2=0.1855, slope=0.1856, intercept=0.0024
# Matched ESN                      features=450 r=0.4026, RMSE=0.9168, MAE=0.7240, R2=0.1424, slope=0.2187, intercept=0.0088
# Random linear features           features=450 r=0.4307, RMSE=0.8934, MAE=0.7279, R2=0.1855, slope=0.1856, intercept=0.0024
# Random nonlinear features        features=450 r=0.4048, RMSE=0.9157, MAE=0.7270, R2=0.1444, slope=0.2203, intercept=0.0094
# Single Lorenz                    features=  3 r=0.0700, RMSE=0.9876, MAE=0.8182, R2=0.0048, slope=0.0053, intercept=-0.0021
# Low-rho non-chaotic Lorenz       features=450 r=0.3226, RMSE=0.9505, MAE=0.7709, R2=0.0781, slope=0.1560, intercept=0.0054
# Homogeneous chaotic Lorenz       features=450 r=0.3088, RMSE=0.9538, MAE=0.7782, R2=0.0717, slope=0.1429, intercept=0.0019
# DynML heterogeneous Lorenz       features=450 r=0.3959, RMSE=0.9163, MAE=0.7319, R2=0.1434, slope=0.2023, intercept=0.0128
#
# ==========================================================================================
# Prediction seed 7/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.2078, RMSE=1.2562, MAE=0.9668, R2=-0.5756, slope=0.2067, intercept=0.0169
# Direct ridge                     features=  4 r=0.4430, RMSE=0.8973, MAE=0.7279, R2=0.1962, slope=0.1959, intercept=0.0055
# Matched ESN                      features=450 r=0.3993, RMSE=0.9316, MAE=0.7268, R2=0.1336, slope=0.2237, intercept=0.0075
# Random linear features           features=450 r=0.4430, RMSE=0.8973, MAE=0.7279, R2=0.1962, slope=0.1959, intercept=0.0055
# Random nonlinear features        features=450 r=0.4250, RMSE=0.9151, MAE=0.7264, R2=0.1640, slope=0.2355, intercept=0.0069
# Single Lorenz                    features=  3 r=0.0805, RMSE=0.9980, MAE=0.8258, R2=0.0057, slope=0.0077, intercept=-0.0058
# Low-rho non-chaotic Lorenz       features=450 r=0.3223, RMSE=0.9622, MAE=0.7764, R2=0.0756, slope=0.1580, intercept=0.0018
# Homogeneous chaotic Lorenz       features=450 r=0.3015, RMSE=0.9683, MAE=0.7813, R2=0.0639, slope=0.1405, intercept=0.0134
# DynML heterogeneous Lorenz       features=450 r=0.3962, RMSE=0.9308, MAE=0.7390, R2=0.1351, slope=0.2153, intercept=0.0022
#
# ==========================================================================================
# Prediction seed 8/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1909, RMSE=1.2711, MAE=0.9769, R2=-0.6109, slope=0.1901, intercept=0.0000
# Direct ridge                     features=  4 r=0.4426, RMSE=0.8981, MAE=0.7304, R2=0.1958, slope=0.1989, intercept=-0.0007
# Matched ESN                      features=450 r=0.4113, RMSE=0.9259, MAE=0.7292, R2=0.1453, slope=0.2327, intercept=0.0019
# Random linear features           features=450 r=0.4426, RMSE=0.8981, MAE=0.7304, R2=0.1958, slope=0.1990, intercept=-0.0007
# Random nonlinear features        features=450 r=0.4186, RMSE=0.9206, MAE=0.7294, R2=0.1550, slope=0.2346, intercept=0.0043
# Single Lorenz                    features=  3 r=0.0431, RMSE=1.0010, MAE=0.8291, R2=0.0011, slope=0.0031, intercept=-0.0011
# Low-rho non-chaotic Lorenz       features=450 r=0.3554, RMSE=0.9469, MAE=0.7656, R2=0.1060, slope=0.1768, intercept=-0.0027
# Homogeneous chaotic Lorenz       features=450 r=0.3143, RMSE=0.9624, MAE=0.7807, R2=0.0766, slope=0.1456, intercept=0.0013
# DynML heterogeneous Lorenz       features=450 r=0.4103, RMSE=0.9214, MAE=0.7376, R2=0.1536, slope=0.2182, intercept=0.0011
#
# ==========================================================================================
# Prediction seed 9/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1970, RMSE=1.2652, MAE=0.9661, R2=-0.5984, slope=0.1960, intercept=0.0140
# Direct ridge                     features=  4 r=0.4472, RMSE=0.8951, MAE=0.7253, R2=0.2000, slope=0.1990, intercept=0.0078
# Matched ESN                      features=450 r=0.3738, RMSE=0.9582, MAE=0.7349, R2=0.0833, slope=0.2286, intercept=0.0054
# Random linear features           features=450 r=0.4472, RMSE=0.8951, MAE=0.7253, R2=0.2000, slope=0.1990, intercept=0.0078
# Random nonlinear features        features=450 r=0.4096, RMSE=0.9264, MAE=0.7270, R2=0.1431, slope=0.2322, intercept=0.0097
# Single Lorenz                    features=  3 r=0.0616, RMSE=0.9990, MAE=0.8239, R2=0.0035, slope=0.0046, intercept=-0.0029
# Low-rho non-chaotic Lorenz       features=450 r=0.3352, RMSE=0.9553, MAE=0.7722, R2=0.0888, slope=0.1638, intercept=0.0096
# Homogeneous chaotic Lorenz       features=450 r=0.3340, RMSE=0.9522, MAE=0.7696, R2=0.0947, slope=0.1549, intercept=0.0059
# DynML heterogeneous Lorenz       features=450 r=0.4014, RMSE=0.9270, MAE=0.7394, R2=0.1420, slope=0.2166, intercept=0.0097
#
# ==========================================================================================
# Prediction seed 10/10
# ==========================================================================================
# Generating matched ESN features
# Generating random linear features
# Generating random nonlinear features
# Generating single Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating low-rho non-chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating homogeneous chaotic Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
# Generating DynML heterogeneous Lorenz features
#     Lorenz feature sample 1/8000
#     Lorenz feature sample 1001/8000
#     Lorenz feature sample 2001/8000
#     Lorenz feature sample 3001/8000
#     Lorenz feature sample 4001/8000
#     Lorenz feature sample 5001/8000
#     Lorenz feature sample 6001/8000
#     Lorenz feature sample 7001/8000
#
# Pooled test metrics, standardized output space
# ----------------------------------------------
# Persistence                      features=  4 r=0.1995, RMSE=1.2608, MAE=0.9639, R2=-0.6122, slope=0.2008, intercept=0.0078
# Direct ridge                     features=  4 r=0.4316, RMSE=0.8959, MAE=0.7288, R2=0.1859, slope=0.1923, intercept=0.0024
# Matched ESN                      features=450 r=0.3888, RMSE=0.9305, MAE=0.7299, R2=0.1219, slope=0.2175, intercept=0.0023
# Random linear features           features=450 r=0.4316, RMSE=0.8960, MAE=0.7288, R2=0.1859, slope=0.1923, intercept=0.0024
# Random nonlinear features        features=450 r=0.4135, RMSE=0.9160, MAE=0.7273, R2=0.1491, slope=0.2320, intercept=0.0026
# Single Lorenz                    features=  3 r=0.0637, RMSE=0.9914, MAE=0.8217, R2=0.0032, slope=0.0055, intercept=0.0045
# Low-rho non-chaotic Lorenz       features=450 r=0.3470, RMSE=0.9414, MAE=0.7649, R2=0.1012, slope=0.1684, intercept=0.0002
# Homogeneous chaotic Lorenz       features=450 r=0.3294, RMSE=0.9481, MAE=0.7694, R2=0.0883, slope=0.1551, intercept=0.0022
# DynML heterogeneous Lorenz       features=450 r=0.4015, RMSE=0.9189, MAE=0.7345, R2=0.1437, slope=0.2141, intercept=-0.0023
#
# Saved pooled metrics
# --------------------
# double_pendulum_matched_ablation_BD_style_by_seed.csv
# double_pendulum_matched_ablation_BD_style_summary.csv
# double_pendulum_matched_ablation_BD_style_table.csv
#
# Table-ready pooled test metrics, standardized output space
# ----------------------------------------------------------
#         Dataset                      Model  Feature dimension       Pearson r            RMSE             MAE               R2 Calibration slope Calibration intercept
# Double pendulum                Persistence                  4 0.1950 ± 0.0064 1.2663 ± 0.0048 0.9715 ± 0.0041 -0.6072 ± 0.0155   0.1946 ± 0.0063       0.0034 ± 0.0056
# Double pendulum               Direct ridge                  4 0.4440 ± 0.0047 0.8950 ± 0.0020 0.7264 ± 0.0020  0.1971 ± 0.0041   0.1979 ± 0.0037       0.0003 ± 0.0028
# Double pendulum                Matched ESN                450 0.3946 ± 0.0099 0.9372 ± 0.0110 0.7282 ± 0.0019  0.1194 ± 0.0206   0.2282 ± 0.0047       0.0010 ± 0.0051
# Double pendulum     Random linear features                450 0.4440 ± 0.0047 0.8950 ± 0.0020 0.7264 ± 0.0020  0.1971 ± 0.0041   0.1980 ± 0.0037       0.0003 ± 0.0028
# Double pendulum  Random nonlinear features                450 0.4163 ± 0.0072 0.9202 ± 0.0043 0.7267 ± 0.0010  0.1514 ± 0.0087   0.2346 ± 0.0048       0.0020 ± 0.0039
# Double pendulum              Single Lorenz                  3 0.0616 ± 0.0097 0.9971 ± 0.0032 0.8236 ± 0.0022  0.0036 ± 0.0011   0.0047 ± 0.0011      -0.0012 ± 0.0021
# Double pendulum Low-rho non-chaotic Lorenz                450 0.3411 ± 0.0091 0.9507 ± 0.0052 0.7694 ± 0.0043  0.0941 ± 0.0083   0.1673 ± 0.0052       0.0001 ± 0.0040
# Double pendulum Homogeneous chaotic Lorenz                450 0.3182 ± 0.0075 0.9581 ± 0.0036 0.7764 ± 0.0025  0.0799 ± 0.0067   0.1476 ± 0.0039      -0.0009 ± 0.0058
# Double pendulum DynML heterogeneous Lorenz                450 0.4051 ± 0.0080 0.9228 ± 0.0048 0.7358 ± 0.0025  0.1466 ± 0.0088   0.2174 ± 0.0053       0.0007 ± 0.0041
#
# Saved variable-wise metrics
# ---------------------------
# double_pendulum_matched_ablation_BD_style_variablewise_by_seed.csv
# double_pendulum_matched_ablation_BD_style_variablewise_summary.csv
# double_pendulum_matched_ablation_BD_style_variablewise_table.csv
#
# Table-ready variable-wise test metrics, standardized output space
# -----------------------------------------------------------------
#         Dataset                      Model  Output        Pearson r            RMSE             MAE               R2 Calibration slope Calibration intercept
# Double pendulum                Persistence theta_1 -0.0266 ± 0.0133 1.4283 ± 0.0087 1.1520 ± 0.0095 -1.0584 ± 0.0395  -0.0268 ± 0.0135      -0.0062 ± 0.0114
# Double pendulum                Persistence theta_2  0.8679 ± 0.0036 0.5119 ± 0.0029 0.4073 ± 0.0028  0.7361 ± 0.0067   0.8666 ± 0.0080       0.0002 ± 0.0085
# Double pendulum                Persistence omega_1 -0.0561 ± 0.0151 1.4527 ± 0.0137 1.1823 ± 0.0122 -1.1051 ± 0.0454  -0.0561 ± 0.0155       0.0094 ± 0.0120
# Double pendulum                Persistence omega_2 -0.0025 ± 0.0156 1.4147 ± 0.0103 1.1444 ± 0.0098 -0.9993 ± 0.0457  -0.0027 ± 0.0158       0.0091 ± 0.0117
# Double pendulum               Direct ridge theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum               Direct ridge theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7721 ± 0.0083       0.0015 ± 0.0086
# Double pendulum               Direct ridge omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum               Direct ridge omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum                Matched ESN theta_1  0.0963 ± 0.0149 1.0338 ± 0.0142 0.8450 ± 0.0057 -0.0783 ± 0.0250   0.0365 ± 0.0042       0.0012 ± 0.0090
# Double pendulum                Matched ESN theta_2  0.8825 ± 0.0047 0.4701 ± 0.0086 0.3592 ± 0.0020  0.7773 ± 0.0088   0.8063 ± 0.0103       0.0026 ± 0.0070
# Double pendulum                Matched ESN omega_1  0.1266 ± 0.0186 1.0588 ± 0.0360 0.8489 ± 0.0063 -0.1211 ± 0.0808   0.0581 ± 0.0071      -0.0019 ± 0.0114
# Double pendulum                Matched ESN omega_2  0.0435 ± 0.0137 1.0485 ± 0.0203 0.8596 ± 0.0081 -0.0977 ± 0.0310   0.0152 ± 0.0046       0.0011 ± 0.0053
# Double pendulum     Random linear features theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum     Random linear features theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7722 ± 0.0083       0.0015 ± 0.0086
# Double pendulum     Random linear features omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum     Random linear features omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum  Random nonlinear features theta_1  0.1106 ± 0.0117 1.0262 ± 0.0134 0.8466 ± 0.0062 -0.0622 ± 0.0225   0.0414 ± 0.0035       0.0072 ± 0.0072
# Double pendulum  Random nonlinear features theta_2  0.8872 ± 0.0028 0.4608 ± 0.0036 0.3583 ± 0.0023  0.7862 ± 0.0050   0.8099 ± 0.0099       0.0013 ± 0.0062
# Double pendulum  Random nonlinear features omega_1  0.1733 ± 0.0158 1.0155 ± 0.0092 0.8401 ± 0.0058 -0.0285 ± 0.0168   0.0711 ± 0.0062       0.0017 ± 0.0084
# Double pendulum  Random nonlinear features omega_2  0.0538 ± 0.0119 1.0438 ± 0.0066 0.8617 ± 0.0039 -0.0881 ± 0.0118   0.0190 ± 0.0041      -0.0034 ± 0.0046
# Double pendulum              Single Lorenz theta_1  0.0086 ± 0.0181 0.9960 ± 0.0065 0.8421 ± 0.0071 -0.0005 ± 0.0008   0.0002 ± 0.0004       0.0006 ± 0.0030
# Double pendulum              Single Lorenz theta_2  0.1223 ± 0.0210 0.9896 ± 0.0085 0.7635 ± 0.0062  0.0145 ± 0.0043   0.0171 ± 0.0050      -0.0015 ± 0.0060
# Double pendulum              Single Lorenz omega_1  0.0222 ± 0.0233 1.0013 ± 0.0060 0.8470 ± 0.0074  0.0003 ± 0.0019   0.0013 ± 0.0014      -0.0018 ± 0.0034
# Double pendulum              Single Lorenz omega_2  0.0114 ± 0.0125 1.0014 ± 0.0063 0.8419 ± 0.0065 -0.0012 ± 0.0012   0.0004 ± 0.0005      -0.0022 ± 0.0025
# Double pendulum Low-rho non-chaotic Lorenz theta_1  0.0741 ± 0.0180 1.0249 ± 0.0091 0.8548 ± 0.0079 -0.0594 ± 0.0102   0.0244 ± 0.0059       0.0022 ± 0.0072
# Double pendulum Low-rho non-chaotic Lorenz theta_2  0.7417 ± 0.0114 0.6715 ± 0.0146 0.5146 ± 0.0102  0.5458 ± 0.0173   0.5988 ± 0.0146      -0.0027 ± 0.0076
# Double pendulum Low-rho non-chaotic Lorenz omega_1  0.1040 ± 0.0105 1.0225 ± 0.0048 0.8502 ± 0.0054 -0.0426 ± 0.0083   0.0346 ± 0.0034      -0.0028 ± 0.0038
# Double pendulum Low-rho non-chaotic Lorenz omega_2  0.0448 ± 0.0165 1.0336 ± 0.0084 0.8579 ± 0.0089 -0.0667 ± 0.0115   0.0136 ± 0.0049       0.0027 ± 0.0082
# Double pendulum Homogeneous chaotic Lorenz theta_1  0.0796 ± 0.0106 1.0206 ± 0.0083 0.8505 ± 0.0072 -0.0505 ± 0.0084   0.0251 ± 0.0032      -0.0047 ± 0.0070
# Double pendulum Homogeneous chaotic Lorenz theta_2  0.6780 ± 0.0105 0.7360 ± 0.0129 0.5553 ± 0.0088  0.4546 ± 0.0151   0.5058 ± 0.0137       0.0034 ± 0.0137
# Double pendulum Homogeneous chaotic Lorenz omega_1  0.1247 ± 0.0130 1.0162 ± 0.0038 0.8467 ± 0.0050 -0.0299 ± 0.0107   0.0417 ± 0.0040      -0.0039 ± 0.0058
# Double pendulum Homogeneous chaotic Lorenz omega_2  0.0654 ± 0.0164 1.0274 ± 0.0042 0.8531 ± 0.0051 -0.0542 ± 0.0110   0.0199 ± 0.0050       0.0009 ± 0.0064
# Double pendulum DynML heterogeneous Lorenz theta_1  0.0632 ± 0.0142 1.0310 ± 0.0109 0.8581 ± 0.0089 -0.0721 ± 0.0148   0.0210 ± 0.0044       0.0001 ± 0.0087
# Double pendulum DynML heterogeneous Lorenz theta_2  0.8770 ± 0.0033 0.4798 ± 0.0036 0.3777 ± 0.0040  0.7681 ± 0.0059   0.7909 ± 0.0110       0.0020 ± 0.0076
# Double pendulum DynML heterogeneous Lorenz omega_1  0.1194 ± 0.0109 1.0226 ± 0.0060 0.8502 ± 0.0052 -0.0429 ± 0.0113   0.0424 ± 0.0035      -0.0011 ± 0.0049
# Double pendulum DynML heterogeneous Lorenz omega_2  0.0583 ± 0.0126 1.0328 ± 0.0086 0.8570 ± 0.0077 -0.0651 ± 0.0128   0.0184 ± 0.0039       0.0006 ± 0.0085
#
# Total time: 1986.04 seconds

# %%
# ============================================================
# DOUBLE-PENDULUM VARIABLE-WISE SUPPLEMENTARY FIGURE
#
# Loads saved variable-wise BD-style metrics only.
# Does NOT rerun any models.
#
# Expected input file:
#   double_pendulum_matched_ablation_BD_style_variablewise_by_seed.csv
#
# Output:
#   double_pendulum_variablewise_metrics_BD_style.jpeg
#   double_pendulum_variablewise_metrics_BD_style.pdf
#   double_pendulum_variablewise_summary_BD_style.csv
#   double_pendulum_variablewise_table_ready_BD_style.csv
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path


# ============================================================
# INPUT FILE
# ============================================================

VARIABLE_METRICS_FILE = Path(
    "double_pendulum_matched_ablation_BD_style_variablewise_by_seed.csv"
)

if not VARIABLE_METRICS_FILE.exists():
    raise FileNotFoundError(f"Could not find {VARIABLE_METRICS_FILE}")


# ============================================================
# OUTPUT FILES
# ============================================================

FIGURE_JPEG = "double_pendulum_variablewise_metrics_BD_style.jpeg"
FIGURE_PDF = "double_pendulum_variablewise_metrics_BD_style.pdf"
SUMMARY_TABLE_FILE = "double_pendulum_variablewise_summary_BD_style.csv"
TABLE_READY_FILE = "double_pendulum_variablewise_table_ready_BD_style.csv"


# ============================================================
# LOAD DATA
# ============================================================

metrics_df = pd.read_csv(VARIABLE_METRICS_FILE)

# Keep test split only
metrics_df = metrics_df[metrics_df["split"] == "test"].copy()


# ============================================================
# MODEL AND OUTPUT ORDER
# ============================================================

model_order = [
    "Persistence",
    "Direct ridge",
    "Matched ESN",
    "Random linear features",
    "Random nonlinear features",
    "Single Lorenz",
    "Low-rho non-chaotic Lorenz",
    "Homogeneous chaotic Lorenz",
    "DynML heterogeneous Lorenz"
]

output_order = [
    "theta_1",
    "theta_2",
    "omega_1",
    "omega_2"
]

label_map = {
    "Persistence": "Persistence",
    "Direct ridge": "Direct\nridge",
    "Matched ESN": "Matched\nESN",
    "Random linear features": "Random\nlinear",
    "Random nonlinear features": "Random\nnonlinear",
    "Single Lorenz": "Single\nLorenz",
    "Low-rho non-chaotic Lorenz": "Low-ρ\nLorenz",
    "Homogeneous chaotic Lorenz": "Homogeneous\nLorenz",
    "DynML heterogeneous Lorenz": "DynML\nheterogeneous"
}

output_label_map = {
    "theta_1": r"$\theta_1$",
    "theta_2": r"$\theta_2$",
    "omega_1": r"$\omega_1$",
    "omega_2": r"$\omega_2$"
}

metrics_df["model"] = pd.Categorical(
    metrics_df["model"],
    categories=model_order,
    ordered=True
)

metrics_df["output"] = pd.Categorical(
    metrics_df["output"],
    categories=output_order,
    ordered=True
)

metrics_df = metrics_df.sort_values(["output", "model", "seed_id"])


# ============================================================
# SUMMARY
# ============================================================

def summarize_variable_metric_df(df):
    rows = []

    grouped = df.groupby(["model", "output"], observed=True)

    for (model, output), group in grouped:
        row = {
            "dataset": "Double pendulum",
            "model": model,
            "output": output,
            "n_seeds": group["seed_id"].nunique()
        }

        for metric in [
            "pearson_r",
            "rmse",
            "mae",
            "r2",
            "calibration_slope",
            "calibration_intercept"
        ]:
            values = group[metric].dropna().values
            n = len(values)

            mean = np.mean(values) if n > 0 else np.nan
            sd = np.std(values, ddof=1) if n > 1 else np.nan
            sem = sd / np.sqrt(n) if n > 1 else np.nan
            ci95 = 1.96 * sem if n > 1 else np.nan

            row[f"{metric}_mean"] = mean
            row[f"{metric}_sd"] = sd
            row[f"{metric}_ci95"] = ci95

        rows.append(row)

    summary = pd.DataFrame(rows)

    summary["model"] = pd.Categorical(
        summary["model"],
        categories=model_order,
        ordered=True
    )

    summary["output"] = pd.Categorical(
        summary["output"],
        categories=output_order,
        ordered=True
    )

    return summary.sort_values(["output", "model"])


summary_df = summarize_variable_metric_df(metrics_df)
summary_df.to_csv(SUMMARY_TABLE_FILE, index=False)


# ============================================================
# TABLE-READY CSV
# ============================================================

def format_mean_ci(mean, ci):
    if pd.isna(mean):
        return "NA"
    if pd.isna(ci):
        return f"{mean:.4f}"
    return f"{mean:.4f} ± {ci:.4f}"


table_rows = []

for _, row in summary_df.iterrows():
    table_rows.append({
        "Dataset": row["dataset"],
        "Model": row["model"],
        "Output": row["output"],
        "Pearson r": format_mean_ci(
            row["pearson_r_mean"],
            row["pearson_r_ci95"]
        ),
        "RMSE": format_mean_ci(
            row["rmse_mean"],
            row["rmse_ci95"]
        ),
        "MAE": format_mean_ci(
            row["mae_mean"],
            row["mae_ci95"]
        ),
        "R2": format_mean_ci(
            row["r2_mean"],
            row["r2_ci95"]
        ),
        "Calibration slope": format_mean_ci(
            row["calibration_slope_mean"],
            row["calibration_slope_ci95"]
        ),
        "Calibration intercept": format_mean_ci(
            row["calibration_intercept_mean"],
            row["calibration_intercept_ci95"]
        )
    })

table_ready_df = pd.DataFrame(table_rows)
table_ready_df.to_csv(TABLE_READY_FILE, index=False)

print("Saved variable-wise summary files")
print("---------------------------------")
print(SUMMARY_TABLE_FILE)
print(TABLE_READY_FILE)
print()
print(table_ready_df.to_string(index=False))


# ============================================================
# PLOTTING HELPERS
# ============================================================

metric_specs = [
    ("pearson_r", "Pearson r", "Pearson r"),
    ("rmse", "RMSE", "RMSE"),
    ("mae", "MAE", "MAE"),
    ("r2", r"$R^2$", r"$R^2$")
]

panel_letters = list("ABCDEFGHIJKLMNOP")


def plot_variable_metric_panel(ax, output_name, metric, ylabel, panel_label):
    plot_summary = summary_df[summary_df["output"] == output_name].copy()
    plot_raw = metrics_df[metrics_df["output"] == output_name].copy()

    plot_summary = plot_summary.sort_values("model")

    models = plot_summary["model"].astype(str).tolist()
    labels = [label_map[m] for m in models]
    x = np.arange(len(models))

    means = plot_summary[f"{metric}_mean"].values
    cis = plot_summary[f"{metric}_ci95"].values

    ax.bar(
        x,
        means,
        yerr=cis,
        capsize=3,
        alpha=0.85,
        edgecolor="black",
        linewidth=0.4
    )

    seed_x = []
    seed_values = []

    for i, model in enumerate(models):
        values = plot_raw[
            plot_raw["model"].astype(str) == model
        ][metric].values

        seed_x.extend([i] * len(values))
        seed_values.extend(values)

    ax.scatter(
        seed_x,
        seed_values,
        color="black",
        s=14,
        alpha=0.75,
        zorder=3
    )

    ax.set_title(panel_label, fontsize=11)
    ax.set_ylabel(ylabel, fontsize=10)
    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=35, ha="right", fontsize=7)
    ax.tick_params(axis="y", labelsize=8)
    ax.grid(True, axis="y", linestyle="--", linewidth=0.5, alpha=0.45)

    if metric in ["pearson_r", "r2"]:
        ymin = min(
            -0.00,
            np.nanmin(means - np.nan_to_num(cis, nan=0.0)) - 0.05
        )
        ymax = min(
            1.05,
            np.nanmax(means + np.nan_to_num(cis, nan=0.0)) + 0.05
        )
        ax.set_ylim(ymin, ymax)


# ============================================================
# MAKE VARIABLE-WISE FIGURE
#
# Layout:
#   Rows    = outputs: theta_1, theta_2, omega_1, omega_2
#   Columns = metrics: Pearson r, RMSE, MAE, R2
# ============================================================

fig, axes = plt.subplots(4, 4, figsize=(18, 14))
axes = axes.flatten()

panel_index = 0

for output_name in output_order:
    for metric, short_label, ylabel in metric_specs:
        ax = axes[panel_index]

        panel_label = (
            f"{panel_letters[panel_index]}. "
            f"{output_label_map[output_name]}: {short_label}"
        )

        plot_variable_metric_panel(
            ax=ax,
            output_name=output_name,
            metric=metric,
            ylabel=ylabel,
            panel_label=panel_label
        )

        panel_index += 1

plt.suptitle(
    "Double-pendulum variable-wise matched baseline and reservoir-ablation comparison",
    fontsize=16
)

plt.tight_layout(rect=[0, 0, 1, 0.965])

plt.savefig(FIGURE_JPEG, dpi=650, bbox_inches="tight")
plt.savefig(FIGURE_PDF, bbox_inches="tight")
plt.show()

print()
print("Saved double-pendulum variable-wise supplementary figure")
print("--------------------------------------------------------")
print(FIGURE_JPEG)
print(FIGURE_PDF)

print()
print("Final variable-wise table-ready test metrics, standardized output space")
print("------------------------------------------------------------------------")
print(table_ready_df.to_string(index=False))
# Out:
# /Users/halders2/.local/lib/python3.13/site-packages/pandas/core/computation/expressions.py:23: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Saved variable-wise summary files
# ---------------------------------
# double_pendulum_variablewise_summary_BD_style.csv
# double_pendulum_variablewise_table_ready_BD_style.csv
#
#         Dataset                      Model  Output        Pearson r            RMSE             MAE               R2 Calibration slope Calibration intercept
# Double pendulum                Persistence theta_1 -0.0266 ± 0.0133 1.4283 ± 0.0087 1.1520 ± 0.0095 -1.0584 ± 0.0395  -0.0268 ± 0.0135      -0.0062 ± 0.0114
# Double pendulum               Direct ridge theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum                Matched ESN theta_1  0.0963 ± 0.0149 1.0338 ± 0.0142 0.8450 ± 0.0057 -0.0783 ± 0.0250   0.0365 ± 0.0042       0.0012 ± 0.0090
# Double pendulum     Random linear features theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum  Random nonlinear features theta_1  0.1106 ± 0.0117 1.0262 ± 0.0134 0.8466 ± 0.0062 -0.0622 ± 0.0225   0.0414 ± 0.0035       0.0072 ± 0.0072
# Double pendulum              Single Lorenz theta_1  0.0086 ± 0.0181 0.9960 ± 0.0065 0.8421 ± 0.0071 -0.0005 ± 0.0008   0.0002 ± 0.0004       0.0006 ± 0.0030
# Double pendulum Low-rho non-chaotic Lorenz theta_1  0.0741 ± 0.0180 1.0249 ± 0.0091 0.8548 ± 0.0079 -0.0594 ± 0.0102   0.0244 ± 0.0059       0.0022 ± 0.0072
# Double pendulum Homogeneous chaotic Lorenz theta_1  0.0796 ± 0.0106 1.0206 ± 0.0083 0.8505 ± 0.0072 -0.0505 ± 0.0084   0.0251 ± 0.0032      -0.0047 ± 0.0070
# Double pendulum DynML heterogeneous Lorenz theta_1  0.0632 ± 0.0142 1.0310 ± 0.0109 0.8581 ± 0.0089 -0.0721 ± 0.0148   0.0210 ± 0.0044       0.0001 ± 0.0087
# Double pendulum                Persistence theta_2  0.8679 ± 0.0036 0.5119 ± 0.0029 0.4073 ± 0.0028  0.7361 ± 0.0067   0.8666 ± 0.0080       0.0002 ± 0.0085
# Double pendulum               Direct ridge theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7721 ± 0.0083       0.0015 ± 0.0086
# Double pendulum                Matched ESN theta_2  0.8825 ± 0.0047 0.4701 ± 0.0086 0.3592 ± 0.0020  0.7773 ± 0.0088   0.8063 ± 0.0103       0.0026 ± 0.0070
# Double pendulum     Random linear features theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7722 ± 0.0083       0.0015 ± 0.0086
# Double pendulum  Random nonlinear features theta_2  0.8872 ± 0.0028 0.4608 ± 0.0036 0.3583 ± 0.0023  0.7862 ± 0.0050   0.8099 ± 0.0099       0.0013 ± 0.0062
# Double pendulum              Single Lorenz theta_2  0.1223 ± 0.0210 0.9896 ± 0.0085 0.7635 ± 0.0062  0.0145 ± 0.0043   0.0171 ± 0.0050      -0.0015 ± 0.0060
# Double pendulum Low-rho non-chaotic Lorenz theta_2  0.7417 ± 0.0114 0.6715 ± 0.0146 0.5146 ± 0.0102  0.5458 ± 0.0173   0.5988 ± 0.0146      -0.0027 ± 0.0076
# Double pendulum Homogeneous chaotic Lorenz theta_2  0.6780 ± 0.0105 0.7360 ± 0.0129 0.5553 ± 0.0088  0.4546 ± 0.0151   0.5058 ± 0.0137       0.0034 ± 0.0137
# Double pendulum DynML heterogeneous Lorenz theta_2  0.8770 ± 0.0033 0.4798 ± 0.0036 0.3777 ± 0.0040  0.7681 ± 0.0059   0.7909 ± 0.0110       0.0020 ± 0.0076
# Double pendulum                Persistence omega_1 -0.0561 ± 0.0151 1.4527 ± 0.0137 1.1823 ± 0.0122 -1.1051 ± 0.0454  -0.0561 ± 0.0155       0.0094 ± 0.0120
# Double pendulum               Direct ridge omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum                Matched ESN omega_1  0.1266 ± 0.0186 1.0588 ± 0.0360 0.8489 ± 0.0063 -0.1211 ± 0.0808   0.0581 ± 0.0071      -0.0019 ± 0.0114
# Double pendulum     Random linear features omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum  Random nonlinear features omega_1  0.1733 ± 0.0158 1.0155 ± 0.0092 0.8401 ± 0.0058 -0.0285 ± 0.0168   0.0711 ± 0.0062       0.0017 ± 0.0084
# Double pendulum              Single Lorenz omega_1  0.0222 ± 0.0233 1.0013 ± 0.0060 0.8470 ± 0.0074  0.0003 ± 0.0019   0.0013 ± 0.0014      -0.0018 ± 0.0034
# Double pendulum Low-rho non-chaotic Lorenz omega_1  0.1040 ± 0.0105 1.0225 ± 0.0048 0.8502 ± 0.0054 -0.0426 ± 0.0083   0.0346 ± 0.0034      -0.0028 ± 0.0038
# Double pendulum Homogeneous chaotic Lorenz omega_1  0.1247 ± 0.0130 1.0162 ± 0.0038 0.8467 ± 0.0050 -0.0299 ± 0.0107   0.0417 ± 0.0040      -0.0039 ± 0.0058
# Double pendulum DynML heterogeneous Lorenz omega_1  0.1194 ± 0.0109 1.0226 ± 0.0060 0.8502 ± 0.0052 -0.0429 ± 0.0113   0.0424 ± 0.0035      -0.0011 ± 0.0049
# Double pendulum                Persistence omega_2 -0.0025 ± 0.0156 1.4147 ± 0.0103 1.1444 ± 0.0098 -0.9993 ± 0.0457  -0.0027 ± 0.0158       0.0091 ± 0.0117
# Double pendulum               Direct ridge omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum                Matched ESN omega_2  0.0435 ± 0.0137 1.0485 ± 0.0203 0.8596 ± 0.0081 -0.0977 ± 0.0310   0.0152 ± 0.0046       0.0011 ± 0.0053
# Double pendulum     Random linear features omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum  Random nonlinear features omega_2  0.0538 ± 0.0119 1.0438 ± 0.0066 0.8617 ± 0.0039 -0.0881 ± 0.0118   0.0190 ± 0.0041      -0.0034 ± 0.0046
# Double pendulum              Single Lorenz omega_2  0.0114 ± 0.0125 1.0014 ± 0.0063 0.8419 ± 0.0065 -0.0012 ± 0.0012   0.0004 ± 0.0005      -0.0022 ± 0.0025
# Double pendulum Low-rho non-chaotic Lorenz omega_2  0.0448 ± 0.0165 1.0336 ± 0.0084 0.8579 ± 0.0089 -0.0667 ± 0.0115   0.0136 ± 0.0049       0.0027 ± 0.0082
# Double pendulum Homogeneous chaotic Lorenz omega_2  0.0654 ± 0.0164 1.0274 ± 0.0042 0.8531 ± 0.0051 -0.0542 ± 0.0110   0.0199 ± 0.0050       0.0009 ± 0.0064
# Double pendulum DynML heterogeneous Lorenz omega_2  0.0583 ± 0.0126 1.0328 ± 0.0086 0.8570 ± 0.0077 -0.0651 ± 0.0128   0.0184 ± 0.0039       0.0006 ± 0.0085
# Saved double-pendulum variable-wise supplementary figure
# --------------------------------------------------------
# double_pendulum_variablewise_metrics_BD_style.jpeg
# double_pendulum_variablewise_metrics_BD_style.pdf
#
# Final variable-wise table-ready test metrics, standardized output space
# ------------------------------------------------------------------------
#         Dataset                      Model  Output        Pearson r            RMSE             MAE               R2 Calibration slope Calibration intercept
# Double pendulum                Persistence theta_1 -0.0266 ± 0.0133 1.4283 ± 0.0087 1.1520 ± 0.0095 -1.0584 ± 0.0395  -0.0268 ± 0.0135      -0.0062 ± 0.0114
# Double pendulum               Direct ridge theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum                Matched ESN theta_1  0.0963 ± 0.0149 1.0338 ± 0.0142 0.8450 ± 0.0057 -0.0783 ± 0.0250   0.0365 ± 0.0042       0.0012 ± 0.0090
# Double pendulum     Random linear features theta_1  0.0612 ± 0.0090 0.9944 ± 0.0066 0.8396 ± 0.0070  0.0027 ± 0.0017   0.0051 ± 0.0006       0.0015 ± 0.0028
# Double pendulum  Random nonlinear features theta_1  0.1106 ± 0.0117 1.0262 ± 0.0134 0.8466 ± 0.0062 -0.0622 ± 0.0225   0.0414 ± 0.0035       0.0072 ± 0.0072
# Double pendulum              Single Lorenz theta_1  0.0086 ± 0.0181 0.9960 ± 0.0065 0.8421 ± 0.0071 -0.0005 ± 0.0008   0.0002 ± 0.0004       0.0006 ± 0.0030
# Double pendulum Low-rho non-chaotic Lorenz theta_1  0.0741 ± 0.0180 1.0249 ± 0.0091 0.8548 ± 0.0079 -0.0594 ± 0.0102   0.0244 ± 0.0059       0.0022 ± 0.0072
# Double pendulum Homogeneous chaotic Lorenz theta_1  0.0796 ± 0.0106 1.0206 ± 0.0083 0.8505 ± 0.0072 -0.0505 ± 0.0084   0.0251 ± 0.0032      -0.0047 ± 0.0070
# Double pendulum DynML heterogeneous Lorenz theta_1  0.0632 ± 0.0142 1.0310 ± 0.0109 0.8581 ± 0.0089 -0.0721 ± 0.0148   0.0210 ± 0.0044       0.0001 ± 0.0087
# Double pendulum                Persistence theta_2  0.8679 ± 0.0036 0.5119 ± 0.0029 0.4073 ± 0.0028  0.7361 ± 0.0067   0.8666 ± 0.0080       0.0002 ± 0.0085
# Double pendulum               Direct ridge theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7721 ± 0.0083       0.0015 ± 0.0086
# Double pendulum                Matched ESN theta_2  0.8825 ± 0.0047 0.4701 ± 0.0086 0.3592 ± 0.0020  0.7773 ± 0.0088   0.8063 ± 0.0103       0.0026 ± 0.0070
# Double pendulum     Random linear features theta_2  0.8781 ± 0.0033 0.4771 ± 0.0033 0.3851 ± 0.0028  0.7708 ± 0.0057   0.7722 ± 0.0083       0.0015 ± 0.0086
# Double pendulum  Random nonlinear features theta_2  0.8872 ± 0.0028 0.4608 ± 0.0036 0.3583 ± 0.0023  0.7862 ± 0.0050   0.8099 ± 0.0099       0.0013 ± 0.0062
# Double pendulum              Single Lorenz theta_2  0.1223 ± 0.0210 0.9896 ± 0.0085 0.7635 ± 0.0062  0.0145 ± 0.0043   0.0171 ± 0.0050      -0.0015 ± 0.0060
# Double pendulum Low-rho non-chaotic Lorenz theta_2  0.7417 ± 0.0114 0.6715 ± 0.0146 0.5146 ± 0.0102  0.5458 ± 0.0173   0.5988 ± 0.0146      -0.0027 ± 0.0076
# Double pendulum Homogeneous chaotic Lorenz theta_2  0.6780 ± 0.0105 0.7360 ± 0.0129 0.5553 ± 0.0088  0.4546 ± 0.0151   0.5058 ± 0.0137       0.0034 ± 0.0137
# Double pendulum DynML heterogeneous Lorenz theta_2  0.8770 ± 0.0033 0.4798 ± 0.0036 0.3777 ± 0.0040  0.7681 ± 0.0059   0.7909 ± 0.0110       0.0020 ± 0.0076
# Double pendulum                Persistence omega_1 -0.0561 ± 0.0151 1.4527 ± 0.0137 1.1823 ± 0.0122 -1.1051 ± 0.0454  -0.0561 ± 0.0155       0.0094 ± 0.0120
# Double pendulum               Direct ridge omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum                Matched ESN omega_1  0.1266 ± 0.0186 1.0588 ± 0.0360 0.8489 ± 0.0063 -0.1211 ± 0.0808   0.0581 ± 0.0071      -0.0019 ± 0.0114
# Double pendulum     Random linear features omega_1  0.1144 ± 0.0173 0.9954 ± 0.0058 0.8424 ± 0.0067  0.0119 ± 0.0037   0.0121 ± 0.0014      -0.0007 ± 0.0040
# Double pendulum  Random nonlinear features omega_1  0.1733 ± 0.0158 1.0155 ± 0.0092 0.8401 ± 0.0058 -0.0285 ± 0.0168   0.0711 ± 0.0062       0.0017 ± 0.0084
# Double pendulum              Single Lorenz omega_1  0.0222 ± 0.0233 1.0013 ± 0.0060 0.8470 ± 0.0074  0.0003 ± 0.0019   0.0013 ± 0.0014      -0.0018 ± 0.0034
# Double pendulum Low-rho non-chaotic Lorenz omega_1  0.1040 ± 0.0105 1.0225 ± 0.0048 0.8502 ± 0.0054 -0.0426 ± 0.0083   0.0346 ± 0.0034      -0.0028 ± 0.0038
# Double pendulum Homogeneous chaotic Lorenz omega_1  0.1247 ± 0.0130 1.0162 ± 0.0038 0.8467 ± 0.0050 -0.0299 ± 0.0107   0.0417 ± 0.0040      -0.0039 ± 0.0058
# Double pendulum DynML heterogeneous Lorenz omega_1  0.1194 ± 0.0109 1.0226 ± 0.0060 0.8502 ± 0.0052 -0.0429 ± 0.0113   0.0424 ± 0.0035      -0.0011 ± 0.0049
# Double pendulum                Persistence omega_2 -0.0025 ± 0.0156 1.4147 ± 0.0103 1.1444 ± 0.0098 -0.9993 ± 0.0457  -0.0027 ± 0.0158       0.0091 ± 0.0117
# Double pendulum               Direct ridge omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum                Matched ESN omega_2  0.0435 ± 0.0137 1.0485 ± 0.0203 0.8596 ± 0.0081 -0.0977 ± 0.0310   0.0152 ± 0.0046       0.0011 ± 0.0053
# Double pendulum     Random linear features omega_2  0.0744 ± 0.0129 0.9984 ± 0.0065 0.8384 ± 0.0066  0.0047 ± 0.0018   0.0055 ± 0.0007      -0.0024 ± 0.0030
# Double pendulum  Random nonlinear features omega_2  0.0538 ± 0.0119 1.0438 ± 0.0066 0.8617 ± 0.0039 -0.0881 ± 0.0118   0.0190 ± 0.0041      -0.0034 ± 0.0046
# Double pendulum              Single Lorenz omega_2  0.0114 ± 0.0125 1.0014 ± 0.0063 0.8419 ± 0.0065 -0.0012 ± 0.0012   0.0004 ± 0.0005      -0.0022 ± 0.0025
# Double pendulum Low-rho non-chaotic Lorenz omega_2  0.0448 ± 0.0165 1.0336 ± 0.0084 0.8579 ± 0.0089 -0.0667 ± 0.0115   0.0136 ± 0.0049       0.0027 ± 0.0082
# Double pendulum Homogeneous chaotic Lorenz omega_2  0.0654 ± 0.0164 1.0274 ± 0.0042 0.8531 ± 0.0051 -0.0542 ± 0.0110   0.0199 ± 0.0050       0.0009 ± 0.0064
# Double pendulum DynML heterogeneous Lorenz omega_2  0.0583 ± 0.0126 1.0328 ± 0.0086 0.8570 ± 0.0077 -0.0651 ± 0.0128   0.0184 ± 0.0039       0.0006 ± 0.0085
