# %%
import os
import scipy.io as sio
import numpy as np
import pandas as pd

data_dir = "./"   # folder with all .mat files

for patient_id in range(1, 13):  # Patients 1–12
    mat_file = os.path.join(data_dir, f"cluster_dataPatients{patient_id}.mat")
    print(f"Loading: {mat_file}")
    
    data = sio.loadmat(mat_file)
    
    # Identify the cell array variable (ignore __metadata__)
    cell_key = [k for k in data.keys() if not k.startswith("__")][0]
    clusters = data[cell_key]  # (1,16) cell array

    out_dir = f"Patient{patient_id}"
    os.makedirs(out_dir, exist_ok=True)

    for idx in range(16):
        old_cluster = idx + 1
        
        # skip cluster 11
        if old_cluster == 11:
            continue
        
        # reindex clusters > 11
        new_cluster = old_cluster - 1 if old_cluster > 11 else old_cluster
        
        # extract MATLAB matrix from cell
        mat = clusters[0, idx]

        # Convert MATLAB object to numpy array properly
        mat = np.array(mat, dtype=object)

        # First column = gene names (string), others = numbers
        # Convert to DataFrame
        df = pd.DataFrame(mat)

        # Save CSV
        out_path = os.path.join(out_dir, f"cluster{new_cluster}.csv")
        df.to_csv(out_path, index=False, header=False)

        print(f"Saved: {out_path} (old cluster {old_cluster})")

print("MATLAB data to CSV: Done!")
# Out:
# Loading: ./cluster_dataPatients1.mat
# Saved: Patient1/cluster1.csv (old cluster 1)
# Saved: Patient1/cluster2.csv (old cluster 2)
# Saved: Patient1/cluster3.csv (old cluster 3)
# Saved: Patient1/cluster4.csv (old cluster 4)
# Saved: Patient1/cluster5.csv (old cluster 5)
# Saved: Patient1/cluster6.csv (old cluster 6)
# Saved: Patient1/cluster7.csv (old cluster 7)
# Saved: Patient1/cluster8.csv (old cluster 8)
# Saved: Patient1/cluster9.csv (old cluster 9)
# Saved: Patient1/cluster10.csv (old cluster 10)
# Saved: Patient1/cluster11.csv (old cluster 12)
# Saved: Patient1/cluster12.csv (old cluster 13)
# Saved: Patient1/cluster13.csv (old cluster 14)
# Saved: Patient1/cluster14.csv (old cluster 15)
# Saved: Patient1/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients2.mat
# Saved: Patient2/cluster1.csv (old cluster 1)
# Saved: Patient2/cluster2.csv (old cluster 2)
# Saved: Patient2/cluster3.csv (old cluster 3)
# Saved: Patient2/cluster4.csv (old cluster 4)
# Saved: Patient2/cluster5.csv (old cluster 5)
# Saved: Patient2/cluster6.csv (old cluster 6)
# Saved: Patient2/cluster7.csv (old cluster 7)
# Saved: Patient2/cluster8.csv (old cluster 8)
# Saved: Patient2/cluster9.csv (old cluster 9)
# Saved: Patient2/cluster10.csv (old cluster 10)
# Saved: Patient2/cluster11.csv (old cluster 12)
# Saved: Patient2/cluster12.csv (old cluster 13)
# Saved: Patient2/cluster13.csv (old cluster 14)
# Saved: Patient2/cluster14.csv (old cluster 15)
# Saved: Patient2/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients3.mat
# Saved: Patient3/cluster1.csv (old cluster 1)
# Saved: Patient3/cluster2.csv (old cluster 2)
# Saved: Patient3/cluster3.csv (old cluster 3)
# Saved: Patient3/cluster4.csv (old cluster 4)
# Saved: Patient3/cluster5.csv (old cluster 5)
# Saved: Patient3/cluster6.csv (old cluster 6)
# Saved: Patient3/cluster7.csv (old cluster 7)
# Saved: Patient3/cluster8.csv (old cluster 8)
# Saved: Patient3/cluster9.csv (old cluster 9)
# Saved: Patient3/cluster10.csv (old cluster 10)
# Saved: Patient3/cluster11.csv (old cluster 12)
# Saved: Patient3/cluster12.csv (old cluster 13)
# Saved: Patient3/cluster13.csv (old cluster 14)
# Saved: Patient3/cluster14.csv (old cluster 15)
# Saved: Patient3/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients4.mat
# Saved: Patient4/cluster1.csv (old cluster 1)
# Saved: Patient4/cluster2.csv (old cluster 2)
# Saved: Patient4/cluster3.csv (old cluster 3)
# Saved: Patient4/cluster4.csv (old cluster 4)
# Saved: Patient4/cluster5.csv (old cluster 5)
# Saved: Patient4/cluster6.csv (old cluster 6)
# Saved: Patient4/cluster7.csv (old cluster 7)
# Saved: Patient4/cluster8.csv (old cluster 8)
# Saved: Patient4/cluster9.csv (old cluster 9)
# Saved: Patient4/cluster10.csv (old cluster 10)
# Saved: Patient4/cluster11.csv (old cluster 12)
# Saved: Patient4/cluster12.csv (old cluster 13)
# Saved: Patient4/cluster13.csv (old cluster 14)
# Saved: Patient4/cluster14.csv (old cluster 15)
# Saved: Patient4/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients5.mat
# Saved: Patient5/cluster1.csv (old cluster 1)
# Saved: Patient5/cluster2.csv (old cluster 2)
# Saved: Patient5/cluster3.csv (old cluster 3)
# Saved: Patient5/cluster4.csv (old cluster 4)
# Saved: Patient5/cluster5.csv (old cluster 5)
# Saved: Patient5/cluster6.csv (old cluster 6)
# Saved: Patient5/cluster7.csv (old cluster 7)
# Saved: Patient5/cluster8.csv (old cluster 8)
# Saved: Patient5/cluster9.csv (old cluster 9)
# Saved: Patient5/cluster10.csv (old cluster 10)
# Saved: Patient5/cluster11.csv (old cluster 12)
# Saved: Patient5/cluster12.csv (old cluster 13)
# Saved: Patient5/cluster13.csv (old cluster 14)
# Saved: Patient5/cluster14.csv (old cluster 15)
# Saved: Patient5/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients6.mat
# Saved: Patient6/cluster1.csv (old cluster 1)
# Saved: Patient6/cluster2.csv (old cluster 2)
# Saved: Patient6/cluster3.csv (old cluster 3)
# Saved: Patient6/cluster4.csv (old cluster 4)
# Saved: Patient6/cluster5.csv (old cluster 5)
# Saved: Patient6/cluster6.csv (old cluster 6)
# Saved: Patient6/cluster7.csv (old cluster 7)
# Saved: Patient6/cluster8.csv (old cluster 8)
# Saved: Patient6/cluster9.csv (old cluster 9)
# Saved: Patient6/cluster10.csv (old cluster 10)
# Saved: Patient6/cluster11.csv (old cluster 12)
# Saved: Patient6/cluster12.csv (old cluster 13)
# Saved: Patient6/cluster13.csv (old cluster 14)
# Saved: Patient6/cluster14.csv (old cluster 15)
# Saved: Patient6/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients7.mat
# Saved: Patient7/cluster1.csv (old cluster 1)
# Saved: Patient7/cluster2.csv (old cluster 2)
# Saved: Patient7/cluster3.csv (old cluster 3)
# Saved: Patient7/cluster4.csv (old cluster 4)
# Saved: Patient7/cluster5.csv (old cluster 5)
# Saved: Patient7/cluster6.csv (old cluster 6)
# Saved: Patient7/cluster7.csv (old cluster 7)
# Saved: Patient7/cluster8.csv (old cluster 8)
# Saved: Patient7/cluster9.csv (old cluster 9)
# Saved: Patient7/cluster10.csv (old cluster 10)
# Saved: Patient7/cluster11.csv (old cluster 12)
# Saved: Patient7/cluster12.csv (old cluster 13)
# Saved: Patient7/cluster13.csv (old cluster 14)
# Saved: Patient7/cluster14.csv (old cluster 15)
# Saved: Patient7/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients8.mat
# Saved: Patient8/cluster1.csv (old cluster 1)
# Saved: Patient8/cluster2.csv (old cluster 2)
# Saved: Patient8/cluster3.csv (old cluster 3)
# Saved: Patient8/cluster4.csv (old cluster 4)
# Saved: Patient8/cluster5.csv (old cluster 5)
# Saved: Patient8/cluster6.csv (old cluster 6)
# Saved: Patient8/cluster7.csv (old cluster 7)
# Saved: Patient8/cluster8.csv (old cluster 8)
# Saved: Patient8/cluster9.csv (old cluster 9)
# Saved: Patient8/cluster10.csv (old cluster 10)
# Saved: Patient8/cluster11.csv (old cluster 12)
# Saved: Patient8/cluster12.csv (old cluster 13)
# Saved: Patient8/cluster13.csv (old cluster 14)
# Saved: Patient8/cluster14.csv (old cluster 15)
# Saved: Patient8/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients9.mat
# Saved: Patient9/cluster1.csv (old cluster 1)
# Saved: Patient9/cluster2.csv (old cluster 2)
# Saved: Patient9/cluster3.csv (old cluster 3)
# Saved: Patient9/cluster4.csv (old cluster 4)
# Saved: Patient9/cluster5.csv (old cluster 5)
# Saved: Patient9/cluster6.csv (old cluster 6)
# Saved: Patient9/cluster7.csv (old cluster 7)
# Saved: Patient9/cluster8.csv (old cluster 8)
# Saved: Patient9/cluster9.csv (old cluster 9)
# Saved: Patient9/cluster10.csv (old cluster 10)
# Saved: Patient9/cluster11.csv (old cluster 12)
# Saved: Patient9/cluster12.csv (old cluster 13)
# Saved: Patient9/cluster13.csv (old cluster 14)
# Saved: Patient9/cluster14.csv (old cluster 15)
# Saved: Patient9/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients10.mat
# Saved: Patient10/cluster1.csv (old cluster 1)
# Saved: Patient10/cluster2.csv (old cluster 2)
# Saved: Patient10/cluster3.csv (old cluster 3)
# Saved: Patient10/cluster4.csv (old cluster 4)
# Saved: Patient10/cluster5.csv (old cluster 5)
# Saved: Patient10/cluster6.csv (old cluster 6)
# Saved: Patient10/cluster7.csv (old cluster 7)
# Saved: Patient10/cluster8.csv (old cluster 8)
# Saved: Patient10/cluster9.csv (old cluster 9)
# Saved: Patient10/cluster10.csv (old cluster 10)
# Saved: Patient10/cluster11.csv (old cluster 12)
# Saved: Patient10/cluster12.csv (old cluster 13)
# Saved: Patient10/cluster13.csv (old cluster 14)
# Saved: Patient10/cluster14.csv (old cluster 15)
# Saved: Patient10/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients11.mat
# Saved: Patient11/cluster1.csv (old cluster 1)
# Saved: Patient11/cluster2.csv (old cluster 2)
# Saved: Patient11/cluster3.csv (old cluster 3)
# Saved: Patient11/cluster4.csv (old cluster 4)
# Saved: Patient11/cluster5.csv (old cluster 5)
# Saved: Patient11/cluster6.csv (old cluster 6)
# Saved: Patient11/cluster7.csv (old cluster 7)
# Saved: Patient11/cluster8.csv (old cluster 8)
# Saved: Patient11/cluster9.csv (old cluster 9)
# Saved: Patient11/cluster10.csv (old cluster 10)
# Saved: Patient11/cluster11.csv (old cluster 12)
# Saved: Patient11/cluster12.csv (old cluster 13)
# Saved: Patient11/cluster13.csv (old cluster 14)
# Saved: Patient11/cluster14.csv (old cluster 15)
# Saved: Patient11/cluster15.csv (old cluster 16)
# Loading: ./cluster_dataPatients12.mat
# Saved: Patient12/cluster1.csv (old cluster 1)
# Saved: Patient12/cluster2.csv (old cluster 2)
# Saved: Patient12/cluster3.csv (old cluster 3)
# Saved: Patient12/cluster4.csv (old cluster 4)
# Saved: Patient12/cluster5.csv (old cluster 5)
# Saved: Patient12/cluster6.csv (old cluster 6)
# Saved: Patient12/cluster7.csv (old cluster 7)
# Saved: Patient12/cluster8.csv (old cluster 8)
# Saved: Patient12/cluster9.csv (old cluster 9)
# Saved: Patient12/cluster10.csv (old cluster 10)
# Saved: Patient12/cluster11.csv (old cluster 12)
# Saved: Patient12/cluster12.csv (old cluster 13)
# Saved: Patient12/cluster13.csv (old cluster 14)
# Saved: Patient12/cluster14.csv (old cluster 15)
# Saved: Patient12/cluster15.csv (old cluster 16)
# Done!
